# %%
import pandas as pd

data = pd.read_csv(r"data\winequality-red.csv")
data.head(5)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
data.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
data.corr().style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_bbf4c_row0_col0, #T_bbf4c_row1_col1, #T_bbf4c_row2_col2, #T_bbf4c_row3_col3, #T_bbf4c_row4_col4, #T_bbf4c_row5_col5, #T_bbf4c_row6_col6, #T_bbf4c_row7_col7, #T_bbf4c_row8_col8, #T_bbf4c_row9_col9, #T_bbf4c_row10_col10, #T_bbf4c_row11_col11 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_bbf4c_row0_col1, #T_bbf4c_row4_col11, #T_bbf4c_row9_col1 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_bbf4c_row0_col2 {
#   background-color: #f08a6c;
#   color: #f1f1f1;
# }
# #T_bbf4c_row0_col3, #T_bbf4c_row4_col10 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_bbf4c_row0_col4 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_bbf4c_row0_col5, #T_bbf4c_row0_col8, #T_bbf4c_row1_col2, #T_bbf4c_row1_col9, #T_bbf4c_row1_col11, #T_bbf4c_row2_col1, #T_bbf4c_row7_col10, #T_bbf4c_row8_col0, #T_bbf4c_row8_col3, #T_bbf4c_row8_col4, #T_bbf4c_row10_col6, #T_bbf4c_row10_col7 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# ...

# %%
import numpy as np
d_arr = np.asarray(data)
X = d_arr[:, :11]
y = d_arr[:, -1]
y = y.reshape(-1,1)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
from sklearn.linear_model import LinearRegression
lin_reg = LinearRegression()

# %%
lin_reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = lin_reg.predict(X_test)

# %%
lin_reg.coef_
# Out:
# array([[ 4.12835075e-02, -1.14952802e+00, -1.77927063e-01,
#          2.78700036e-02, -1.87340739e+00,  2.68362616e-03,
#         -2.77748370e-03, -3.15166657e+01, -2.54486051e-01,
#          9.24040106e-01,  2.67797417e-01]])

# %%
lin_reg.intercept_
# Out:
# array([34.99871063])

# %%
from sklearn.metrics import mean_squared_error, root_mean_squared_error, mean_absolute_error, mean_absolute_percentage_error
print("Mean squared error: ", mean_squared_error(y_pred, y_test))
print("Mean absolute error: ", mean_absolute_error(y_pred, y_test))
print("Root mean squared error: ", root_mean_squared_error(y_pred, y_test))
print(f"Mean absolute percentage error: {mean_absolute_percentage_error(y_pred, y_test)*100}%")
print("R score: ", lin_reg.score(X_test, y_test))
# Out:
# Mean squared error:  0.38447119782012334
# Mean absolute error:  0.4696330928661091
# Root mean squared error:  0.6200574149384259
# Mean absolute percentage error: 8.26871538970771%
# R score:  0.3283887639580241
